# %% [markdown]
# <a href="https://colab.research.google.com/github/MokuaEnock/Instagram-Agent/blob/main/group_4_14_9_2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#while loop
count = 1

while count <= 5:
    print(count)
    count += 1

# count <= 5
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
#while loop
count = 1

while count <= 5:
  print(f"Current value of count is: {count}")
  count += 1
  print(f"Updated value of count is {count}")
# Out:
# Current value of count is: 1
# Updated value of count is 2
# Current value of count is: 2
# Updated value of count is 3
# Current value of count is: 3
# Updated value of count is 4
# Current value of count is: 4
# Updated value of count is 5
# Current value of count is: 5
# Updated value of count is 6

# %%
#current value of count
count
# Out:
# 6

# %%
score = 65

if score >= 80:
    print("Grade A")
elif score >= 60:
    print("Grade B")
else:
    print("Keep Pushing!!")
# Out:
# Grade B

# %%
score = 9

if type(score) == int:
    print("Integer")
else:
  print("Not integer")
# Out:
# Integer

# %%
user_input = input("What was your score in Programming? ")

# 1. Check if input is a valid positive integer
if not user_input.isdigit():
    print("Kindly ensure your score is a valid whole number between 5 and 99.")

else:
    score = int(user_input)

    # 2. Check if score is within the 5 to 99 range
    if not (5 <= score <= 99):
        print("Kindly ensure your score is a number between 5 and 99.")

    # 3. Grade valid scores
    else:
        if score >= 80:
            print("Grade B")
        elif score >= 60:
            print("Grade A")
        else:
            print("Keep Pushing!!")
# Out:
# What was your score in Programming? 50
# Keep Pushing!!

# %%
a = 999999

if type(a) != int:
    print("Not an integer")

elif not (5 <= a <= 95):
    print("Number must be between 5 and 99")

else:
    print("Major Integer")
# Out:
# Number must be between 5 and 99

# %%
##discuss this code cell

secret = 7
guess = 0

while guess != secret:
    guess = int(input("Guess the number: "))
    if guess < secret:
        print("Too low")
    elif guess > secret:
        print("Too high")
    else:
        print("Correct! You guessed it.")
# Out:
# Guess the number: 90
# Too high
# Guess the number: 50
# Too high
# Guess the number: -10
# Too low
# Guess the number: 4
# Too low
# Guess the number: 8
# Too high
# Guess the number: 7
# Correct! You guessed it.

# %%
## Functions

# %%
#refine the greet_a function to take first_name and second_name from the user(asks user for input)
# prints out the welcome message

# %%
def greet_a():
  first_name = input("What is your first name?")
  second_name = input("What is your second name?")
  print(f"Welcome {first_name} {second_name}")

# %%
def greet_b(first_name, second_name):
  print(f"Welcome {first_name} {second_name}") # string interpolation

# %%
# greet_b("Enock", "Mokua")
# greet_b(second_name="Mokua", first_name="Enock")
# greet_b("Mokua", "Enock")

say_hello= lambda first_name, second_name: f"Welcome {first_name} {second_name}"

print(say_hello(first_name="Enock", second_name="Mokua"))
# Out:
# Welcome Enock Mokua

# %%
print("Welcom Enock Mokua")
print("Welcom Lauryne Mwaura")
print("Welcom Lauryn")

# %%
# greet_a()

# %%
# with arguments = parameters = greet_a()
# without arguments or parameters =
